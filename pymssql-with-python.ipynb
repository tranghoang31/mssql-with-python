# %% [markdown]
# # Install ipython to write SQL query with Python

# %%
# SQL Magic Function
# !pip install ipython-sql

# ORM for databases
# !pip install sqlalchemy
# Out:
# Requirement already satisfied: ipython-sql in c:\users\mihht\desktop\sql-with-python\env\lib\site-packages (0.5.0)
# Requirement already satisfied: prettytable in c:\users\mihht\desktop\sql-with-python\env\lib\site-packages (from ipython-sql) (3.9.0)
# Requirement already satisfied: ipython in c:\users\mihht\desktop\sql-with-python\env\lib\site-packages (from ipython-sql) (8.15.0)
# Requirement already satisfied: sqlalchemy>=2.0 in c:\users\mihht\desktop\sql-with-python\env\lib\site-packages (from ipython-sql) (2.0.22)
# Requirement already satisfied: sqlparse in c:\users\mihht\desktop\sql-with-python\env\lib\site-packages (from ipython-sql) (0.4.4)
# Requirement already satisfied: six in c:\users\mihht\desktop\sql-with-python\env\lib\site-packages (from ipython-sql) (1.16.0)
# Requirement already satisfied: ipython-genutils in c:\users\mihht\desktop\sql-with-python\env\lib\site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\mihht\desktop\sql-with-python\env\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (4.7.1)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\mihht\desktop\sql-with-python\env\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (3.0.0)
# Requirement already satisfied: backcall in c:\users\mihht\desktop\sql-with-python\env\lib\site-packages (from ipython->ipython-sql) (0.2.0)
# Requirement already satisfied: decorator in c:\users\mihht\desktop\sql-with-python\env\lib\site-packages (from ipython->ipython-sql) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\mihht\desktop\sql-with-python\env\lib\site-packages (from ipython->ipython-sql) (0.18.1)
# Requirement already satisfied: matplotlib-inline in c:\users\mihht\desktop\sql-with-python\env\lib\site-packages (from ipython->ipython-sql) (0.1.6)
# Requirement already satisfied: pickleshare in c:\users\mihht\desktop\sql-with-python\env\lib\site-packages (from ipython->ipython-sql) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\mihht\desktop\sql-with-python\env\lib\site-packages (from ipython->ipython-sql) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\mihht\desktop\sql-with-python\env\lib\site-packages (from ipython->ipython-sql) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\mihht\desktop\sql-with-python\env\lib\site-packages (from ipython->ipython-sql) (0.2.0)
# Requirement already satisfied: traitlets>=5 in c:\users\mihht\desktop\sql-with-python\env\lib\site-packages (from ipython->ipython-sql) (5.7.1)
# Requirement already satisfied: colorama in c:\users\mihht\desktop\sql-with-python\env\lib\site-packages (from ipython->ipython-sql) (0.4.6)
# Requirement already satisfied: wcwidth in c:\users\mihht\desktop\sql-with-python\env\lib\site-packages (from prettytable->ipython-sql) (0.2.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\mihht\desktop\sql-with-python\env\lib\site-packages (from jedi>=0.16->ipython->ipython-sql) (0.8.3)
# Requirement already satisfied: executing in c:\users\mihht\desktop\sql-with-python\env\lib\site-packages (from stack-data->ipython->ipython-sql) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\mihht\desktop\sql-with-python\env\lib\site-packages (from stack-data->ipython->ipython-sql) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\mihht\desktop\sql-with-python\env\lib\site-packages (from stack-data->ipython->ipython-sql) (0.2.2)
# Requirement already satisfied: sqlalchemy in c:\users\mihht\desktop\sql-with-python\env\lib\site-packages (2.0.22)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\mihht\desktop\sql-with-python\env\lib\site-packages (from sqlalchemy) (4.7.1)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\mihht\desktop\sql-with-python\env\lib\site-packages (from sqlalchemy) (3.0.0)

# %%
# Import libraries
import pymssql
import pandas as pd

# Function allows to connect to MSSQL database
# %load_ext sql
# %config SqlMagic.autocommit=False
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %% [markdown]
# # Setup and connect to database

# %%
# Setup URI and database

server = "DESKTOP-184SUKT"
user = 'tranghoang'
pw = 'aa'
db = "SQLwithPython"
port = '1433'

# %%
# Define the connection using variables

conn = pymssql.connect(server,user,pw,db,port)

# %%
# Setup the cursor and execute a sample query to check if it's connected successfully
cur = conn.cursor()

# Create new employee table 

cur.execute(
'''
CREATE TABLE employee
(
employee_id INT PRIMARY KEY,
first_name VARCHAR(50),
last_name VARCHAR(50),
email VARCHAR(50),
hire_date DATE,
shop_name VARCHAR(50),
salary INT
)
'''
           )
conn.commit()

# %% [markdown]
# # Read coffeeshop.csv file in pandas dataframe

# %%
df = pd.read_csv('coffeeshop.csv')

# %%
df
# Out:
#     employee_id first_name   last_name                           email  \
# 0         54733      Vonni     Davsley            vdavsley0@joomla.org
# 1         49009       Cary  Brauninger  cbrauninger1@independent.co.uk
# 2         59278   Gerianna   Tolcharde                             NaN
# 3         92214     Helene     Bealing                             NaN
# 4         32890     Vivien   McCrackem                             NaN
# ..          ...        ...         ...                             ...
# 95        29728    Pauline        Geer                  pgeer2n@ca.gov
# 96        20957    Madison      Rudram                 mrudram2o@is.gd
# 97        54628      Giffy     Creeboe         gcreeboe2p@japanpost.jp
# 98        20192     Tracee     Iorizzi         tiorizzi2q@stanford.edu
# 99        69997       Drew       Gokes                             NaN
#
#      hire_date       shop_name  salary
# 0   21/03/2016     Urban Grind    9253
# 1   26/08/2014  Common Grounds   45036
# 2   06/09/2019  Common Grounds   37007
# 3   12/11/2022     Urban Grind   13118
# 4   12/02/2019  Common Grounds   59034
# ..         ...             ...     ...
# 95  24/06/2021  Common Grounds   65636
# 96  16/06/2015      Early Rise   26738
# 97  16/10/2013  Common Grounds   55532
# 98  30/09/2021      Early Rise   10051
# 99  23/05/2022  Common Grounds   49343
#
# [100 rows x 7 columns]

# %% [markdown]
# # Explore Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   employee_id  100 non-null    int64
#  1   first_name   100 non-null    object
#  2   last_name    100 non-null    object
#  3   email        74 non-null     object
#  4   hire_date    100 non-null    object
#  5   shop_name    100 non-null    object
#  6   salary       100 non-null    int64
# dtypes: int64(2), object(5)
# memory usage: 5.6+ KB

# %%
df.salary.describe()
# Out:
# count      100.000000
# mean     40492.380000
# std      17934.502088
# min       9253.000000
# 25%      26269.500000
# 50%      40787.000000
# 75%      57202.500000
# max      67797.000000
# Name: salary, dtype: float64

# %%
df.email.value_counts(dropna=True)
# Out:
# email
# vdavsley0@joomla.org          1
# clabrenz23@unicef.org         1
# dshannahan20@linkedin.com     1
# karnecke1z@cyberchimps.com    1
# cculver1x@cbsnews.com         1
#                              ..
# tmcclintonz@chron.com         1
# ebronoty@google.cn            1
# mfilkinx@prweb.com            1
# pdrinanw@comsenz.com          1
# tiorizzi2q@stanford.edu       1
# Name: count, Length: 74, dtype: int64

# %% [markdown]
# # Convert [hire_date] data type from str to date time

# %%
df['hire_date'] = pd.to_datetime(df['hire_date'], dayfirst = True)

# %%
df['hire_date']
# Out:
# 0    2016-03-21
# 1    2014-08-26
# 2    2019-09-06
# 3    2022-11-12
# 4    2019-02-12
#         ...
# 95   2021-06-24
# 96   2015-06-16
# 97   2013-10-16
# 98   2021-09-30
# 99   2022-05-23
# Name: hire_date, Length: 100, dtype: datetime64[ns]

# %% [markdown]
# # Remove all null values

# %%
new_df = df.dropna()

new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 74 entries, 0 to 98
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   employee_id  74 non-null     int64
#  1   first_name   74 non-null     object
#  2   last_name    74 non-null     object
#  3   email        74 non-null     object
#  4   hire_date    74 non-null     datetime64[ns]
#  5   shop_name    74 non-null     object
#  6   salary       74 non-null     int64
# dtypes: datetime64[ns](1), int64(2), object(4)
# memory usage: 4.6+ KB

# %%
new_df
# Out:
#     employee_id first_name   last_name                           email  \
# 0         54733      Vonni     Davsley            vdavsley0@joomla.org
# 1         49009       Cary  Brauninger  cbrauninger1@independent.co.uk
# 5          8194    Jeffrey      Curran             jcurran5@scribd.com
# 6         73681   Anabelle      Bianco              abianco6@fotki.com
# 7          4058     Grover  McGoldrick     gmcgoldrick7@prnewswire.com
# ..          ...        ...         ...                             ...
# 94         4124    Candice      Brasse         cbrasse2m@homestead.com
# 95        29728    Pauline        Geer                  pgeer2n@ca.gov
# 96        20957    Madison      Rudram                 mrudram2o@is.gd
# 97        54628      Giffy     Creeboe         gcreeboe2p@japanpost.jp
# 98        20192     Tracee     Iorizzi         tiorizzi2q@stanford.edu
#
#     hire_date       shop_name  salary
# 0  2016-03-21     Urban Grind    9253
# 1  2014-08-26  Common Grounds   45036
# 5  2014-06-23     Urban Grind   22986
# 6  2016-05-04     Urban Grind   50899
# 7  2020-05-22  Common Grounds   57471
# ..        ...             ...     ...
# 94 2016-10-10      Early Rise   67797
# 95 2021-06-24  Common Grounds   65636
# 96 2015-06-16      Early Rise   26738
# 97 2013-10-16  Common Grounds   55532
# 98 2021-09-30      Early Rise   10051
#
# [74 rows x 7 columns]

# %%
new_df.value_counts(dropna = False)
# Out:
# employee_id  first_name  last_name    email                     hire_date   shop_name       salary
# 1037         Pearce      Drinan       pdrinanw@comsenz.com      2023-02-04  Early Rise      16557     1
# 82297        Alanna      Rowell       arowell1r@friendfeed.com  2022-09-04  Early Rise      16377     1
# 79816        Cyrillus    Hug          chug2b@jimdo.com          2015-04-03  Common Grounds  30608     1
# 76862        Shell       Dumbrell     sdumbrell1d@taobao.com    2010-09-11  Urban Grind     63533     1
# 73862        Poppy       Mattiessen   pmattiessen18@ebay.com    2012-11-27  Common Grounds  21846     1
#                                                                                                      ..
# 27157        Idalia      Guillot      iguillot1j@skyrock.com    2022-09-30  Common Grounds  35995     1
# 23960        Elinore     Phittiplace  ephittiplace1h@alexa.com  2018-12-21  Urban Grind     13560     1
# 23754        Zilvia      Gingell      zgingell1s@columbia.edu   2021-05-28  Common Grounds  47782     1
# 21218        Derrick     Hethron      dhethroni@ucla.edu        2015-03-06  Common Grounds  30453     1
# 98190        Elwira      Bronot       ebronoty@google.cn        2021-02-11  Common Grounds  22779     1
# Name: count, Length: 74, dtype: int64

# %% [markdown]
# # Insert values into the employee table in the SQLwithPython database

# %%
for i, row in new_df.iterrows():
    cur.execute(
    '''
    INSERT INTO employee
    (employee_id, first_name, last_name, email, hire_date, shop_name, salary)
    VALUES (%s, %s, %s, %s, %s, %s, %s)
    ''', tuple(row))
    
conn.commit()
# Out:
# ---------------------------------------------------------------------------
# MSSQLDatabaseException                    Traceback (most recent call last)
# File src\pymssql\_pymssql.pyx:278, in pymssql._pymssql.Connection.commit()
#
# File src\pymssql\_mssql.pyx:1055, in pymssql._mssql.MSSQLConnection.execute_non_query()
#
# File src\pymssql\_mssql.pyx:1076, in pymssql._mssql.MSSQLConnection.execute_non_query()
#
# File src\pymssql\_mssql.pyx:1250, in pymssql._mssql.MSSQLConnection.format_and_run_query()
#
# File src\pymssql\_mssql.pyx:1788, in pymssql._mssql.check_cancel_and_raise()
#
# File src\pymssql\_mssql.pyx:1834, in pymssql._mssql.raise_MSSQLDatabaseException()
#
# MSSQLDatabaseException: (3902, b'The COMMIT TRANSACTION request has no corresponding BEGIN TRANSACTION.DB-Lib error message 20018, severity 16:\nGeneral SQL Server error: Check messages from the SQL Server\n')
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[139], line 9
#       1 for i, row in new_df.iterrows():
#       2     cur.execute(
#       3     '''
#       4     INSERT INTO employee
#       5     (employee_id, first_name, last_name, email, hire_date, shop_name, salary)
#       6     VALUES (%s, %s, %s, %s, %s, %s, %s)
#       7     ''', tuple(row))
# ----> 9 conn.commit()
#
# File src\pymssql\_pymssql.pyx:281, in pymssql._pymssql.Connection.commit()
#
# OperationalError: Cannot commit transaction: (3902, b'The COMMIT TRANSACTION request has no corresponding BEGIN TRANSACTION.DB-Lib error message 20018, severity 16:\nGeneral SQL Server error: Check messages from the SQL Server\n')

# %% [markdown]
# # Connect to SQL database via pymssql driver with SQLAlchemy format

# %%
conn_string = 'mssql+pymssql://tranghoang:aa@DESKTOP-184SUKT/SQLwithPython'

# %sql $conn_string

# %% [markdown]
# # Execute sample queries

# %%
# %sql SELECT * FROM coffeeshop$;
# Out:
#  * mssql+pymssql://tranghoang:***@DESKTOP-184SUKT/SQLwithPython
# Done.
# [(54733.0, 'Vonni', 'Davsley', 'vdavsley0@joomla.org', '21/03/2016', 'Urban Grind', 9253.0),
#  (49009.0, 'Cary', 'Brauninger', 'cbrauninger1@independent.co.uk', '26/08/2014', 'Common Grounds', 45036.0),
#  (59278.0, 'Gerianna', 'Tolcharde', None, '6/9/2019', 'Common Grounds', 37007.0),
#  (92214.0, 'Helene', 'Bealing', None, '12/11/2022', 'Urban Grind', 13118.0),
#  (32890.0, 'Vivien', 'McCrackem', None, '12/2/2019', 'Common Grounds', 59034.0),
#  (8194.0, 'Jeffrey', 'Curran', 'jcurran5@scribd.com', '23/06/2014', 'Urban Grind', 22986.0),
#  (73681.0, 'Anabelle', 'Bianco', 'abianco6@fotki.com', '4/5/2016', 'Urban Grind', 50899.0),
#  (4058.0, 'Grover', 'McGoldrick', 'gmcgoldrick7@prnewswire.com', '22/05/2020', 'Common Grounds', 57471.0),
#  (5452.0, 'Ivie', 'Shynn', 'ishynn8@ucoz.ru', '27/03/2022', 'Early Rise', 31542.0),
#  (19965.0, 'Leilah', 'Wildbore', 'lwildbore9@amazon.com', '21/02/2023', 'Common Grounds', 20559.0),
#  (90279.0, 'Lindsay', 'Frankland', 'lfranklanda@japanpost.jp', '20/05/2022', 'Common Grounds', 10402.0),
#  (76804.0, 'Alphonse', 'Pendry', None, '4/8/2010', 'Early Rise', 66454.0),
#  (70518.0, 'Liam', 'Fisbburne', 'lfisbburnec@canalblog.com', '10/1/2023', 'Urban Grind', 24392.0),
#  (40264.0, 'Loren', 'Freda', None, '27/07/2022', 'Urban Grind', 63498.0),
#  (45701.0, 'Abelard', 'MacDougall', 'amacdougalle@comsenz.com', '8/9/2020', 'Common Grounds', 11433.0),
#  (81457.0, 'Bennett', 'Mebes', 'bmebesf@123-reg.co.uk', '18/03/2012', 'Common Grounds', 33651.0),
#  (86534.0, 'Brady', 'Clothier', 'bclothierg@microsoft.com', '20/12/2019', 'Early Rise', 62386.0),
#  (25521.0, 'Elsie', 'Romanetti', None, '6/11/2020', 'Early Rise', 45077.0),
#  (21218.0, 'Derrick', 'Hethron', 'dhethroni@ucla.edu', '6/3/2015', 'Common Grounds', 30453.0),
#  (24171.0, 'Enoch', 'Blazy', None, '4/3/2014', 'Urban Grind', 67157.0),
#  (44757.0, 'Corrina', 'Basilone', 'cbasilonek@bbb.org', '17/10/2014', 'Urban Grind', 64204.0),
#  (86922.0, 'Rollo', 'Pilgram', 'rpilgraml@booking.com', '12/6/2021', 'Early Rise', 44894.0),
#  (69448.0, 'Norry', 'MacAdam', 'nmacadamm@ucla.edu', '17/03/2022', 'Urban Grind', 28640.0),
#  (18551.0, 'Gert', 'Screeton', 'gscreetonn@nba.com', '1/8/2021', 'Early Rise', 66121.0),
#  (57063.0, 'Jacquelin', 'Caple', None, '7/2/2017', 'Early Rise', 11908.0),
#  (93911.0, 'Cecilla', 'Chesman', 'cchesmanp@bizjournals.com', '21/12/2014', 'Urban Grind', 38341.0),
#  (82791.0, 'Cthrine', 'Iannuzzi', None, '1/5/2012', 'Early Rise', 25560.0),
#  (90963.0, 'Darin', 'Pithie', 'dpithier@studiopress.com', '20/10/2014', 'Urban Grind', 61056.0),
#  (22100.0, 'Waneta', 'Pendered', None, '11/10/2020', 'Common Grounds', 12084.0),
#  (36338.0, 'Rosetta', 'MacConnulty', 'rmacconnultyt@narod.ru', '13/07/2012', 'Urban Grind', 61653.0),
#  (15212.0, 'Terra', 'Bister', 'tbisteru@sakura.ne.jp', '25/07/2015', 'Early Rise', 47745.0),
#  (27723.0, 'Wittie', 'Justice', None, '29/01/2015', 'Early Rise', 37286.0),
#  (1037.0, 'Pearce', 'Drinan', 'pdrinanw@comsenz.com', '4/2/2023', 'Early Rise', 16557.0),
#  (71408.0, 'Merry', 'Filkin', 'mfilkinx@prweb.com', '19/08/2016', 'Common Grounds', 65494.0),
#  (98190.0, 'Elwira', 'Bronot', 'ebronoty@google.cn', '11/2/2021', 'Common Grounds', 22779.0),
#  (37337.0, 'Tobye', 'McClinton', 'tmcclintonz@chron.com', '3/6/2020', 'Early Rise', 26506.0),
#  (13244.0, 'Marybelle', 'Craft', 'mcraft10@macromedia.com', '24/10/2021', 'Urban Grind', 42076.0),
#  (60495.0, 'Aimee', 'Arthan', 'aarthan11@epa.gov', '20/02/2016', 'Early Rise', 67620.0),
#  (62627.0, 'Anne', 'Kohnert', 'akohnert12@arizona.edu', '13/01/2015', 'Common Grounds', 17675.0),
#  (36401.0, 'Geri', 'Albion', None, '17/08/2012', 'Urban Grind', 14933.0),
#  (83932.0, 'Sacha', 'Getten', 'sgetten14@fotki.com', '5/7/2011', 'Early Rise', 56947.0),
#  (91642.0, 'Noby', 'Leng', 'nleng15@tinyurl.com', '17/05/2016', 'Common Grounds', 57547.0),
#  (12133.0, 'Jermaine', 'Borleace', 'jborleace16@woothemes.com', '25/11/2021', 'Common Grounds', 58816.0),
#  (2472.0, 'Jabez', 'Boatright', 'jboatright17@cdbaby.com', '30/03/2012', 'Urban Grind', 37117.0),
#  (73862.0, 'Poppy', 'Mattiessen', 'pmattiessen18@ebay.com', '27/11/2012', 'Common Grounds', 21846.0),
#  (52875.0, 'Claretta', 'Brient', 'cbrient19@google.fr', '3/11/2011', 'Urban Grind', 29728.0),
#  (36236.0, 'Janeczka', 'Antonutti', None, '22/05/2012', 'Early Rise', 32056.0),
#  (66608.0, 'Earvin', 'Kermott', 'ekermott1b@hostgator.com', '2/1/2020', 'Common Grounds', 49253.0),
#  (74501.0, 'Kelsy', 'Streak', None, '5/7/2020', 'Early Rise', 41881.0),
#  (76862.0, 'Shell', 'Dumbrell', 'sdumbrell1d@taobao.com', '11/9/2010', 'Urban Grind', 63533.0),
#  (92270.0, 'Robena', 'Kennford', None, '12/12/2021', 'Early Rise', 45188.0),
#  (93396.0, 'Shirlee', 'Guesford', None, '24/05/2022', 'Urban Grind', 20283.0),
#  (1091.0, 'Nolana', 'Feavearyear', 'nfeavearyear1g@yellowpages.com', '17/11/2013', 'Early Rise', 66580.0),
#  (23960.0, 'Elinore', 'Phittiplace', 'ephittiplace1h@alexa.com', '21/12/2018', 'Urban Grind', 13560.0),
#  (69452.0, 'Analiese', 'Parker', 'aparker1i@auda.org.au', '23/06/2022', 'Common Grounds', 40807.0),
#  (27157.0, 'Idalia', 'Guillot', 'iguillot1j@skyrock.com', '30/09/2022', 'Common Grounds', 35995.0),
#  (41410.0, 'Baryram', 'Eddis', 'beddis1k@accuweather.com', '1/11/2016', 'Early Rise', 43402.0),
#  (10854.0, 'Meade', 'Makey', 'mmakey1l@europa.eu', '15/02/2020', 'Urban Grind', 65513.0),
#  (38742.0, 'Mychal', 'Idill', 'midill1m@plala.or.jp', '23/07/2018', 'Early Rise', 61899.0),
#  (14691.0, 'Ced', 'Marsh', 'cmarsh1n@google.com', '28/08/2020', 'Early Rise', 33527.0),
#  (11497.0, 'Hermia', 'Sitlington', 'hsitlington1o@arizona.edu', '14/04/2012', 'Urban Grind', 55136.0),
#  (94533.0, 'Rora', 'Whereat', 'rwhereat1p@dion.ne.jp', '18/06/2018', 'Urban Grind', 59639.0),
#  (76268.0, 'Bernhard', 'McShane', None, '13/08/2020', 'Urban Grind', 57113.0),
#  (82297.0, 'Alanna', 'Rowell', 'arowell1r@friendfeed.com', '4/9/2022', 'Early Rise', 16377.0),
#  (23754.0, 'Zilvia', 'Gingell', 'zgingell1s@columbia.edu', '28/05/2021', 'Common Grounds', 47782.0),
#  (8413.0, 'Vikky', 'Kelcey', 'vkelcey1t@sciencedirect.com', '27/07/2014', 'Common Grounds', 65685.0),
#  (63323.0, 'Maria', 'Schleswig-Holstein', 'mschleswigholstein1u@eventbrite.com', '17/12/2020', 'Urban Grind', 50603.0),
#  (73602.0, 'Efrem', 'Tripcony', None, '15/02/2020', 'Urban Grind', 19021.0),
#  (93937.0, 'Teddy', 'Sterling', 'tsterling1w@ucoz.com', '19/11/2012', 'Urban Grind', 53767.0),
#  (82450.0, 'Clemens', 'Culver', 'cculver1x@cbsnews.com', '8/12/2021', 'Urban Grind', 40162.0),
#  (93316.0, 'Lara', 'Lockett', None, '27/07/2017', 'Common Grounds', 60465.0),
#  (97654.0, 'Kimmy', 'Arnecke', 'karnecke1z@cyberchimps.com', '1/5/2020', 'Early Rise', 29915.0),
#  (97247.0, 'Dinny', 'Shannahan', 'dshannahan20@linkedin.com', '21/04/2011', 'Early Rise', 21209.0),
#  (42319.0, 'Base', 'Amoss', 'bamoss21@1688.com', '18/05/2019', 'Early Rise', 14716.0),
#  (92447.0, 'Verine', 'Soppit', None, '19/04/2011', 'Urban Grind', 13824.0),
#  (43994.0, 'Cherey', 'Labrenz', 'clabrenz23@unicef.org', '4/2/2010', 'Urban Grind', 41555.0),
#  (16025.0, 'Lorenza', 'Holleworth', 'lholleworth24@state.tx.us', '27/05/2020', 'Early Rise', 32202.0),
#  (69650.0, 'Dame', 'Tomalin', None, '15/08/2019', 'Urban Grind', 36845.0),
#  (92473.0, 'Christoforo', 'Blais', 'cblais26@amazon.co.uk', '16/02/2019', 'Early Rise', 22592.0),
#  (69050.0, 'Alta', 'Iredale', 'airedale27@ucoz.com', '14/09/2019', 'Common Grounds', 61446.0),
#  (43553.0, 'Gratia', 'Tolussi', 'gtolussi28@bloglines.com', '14/10/2019', 'Common Grounds', 27925.0),
#  (19546.0, 'Marja', 'Halt', 'mhalt29@webs.com', '6/11/2013', 'Common Grounds', 55570.0),
#  (4968.0, 'Forrester', 'Mizzi', None, '14/05/2019', 'Urban Grind', 31757.0),
#  (79816.0, 'Cyrillus', 'Hug', 'chug2b@jimdo.com', '3/4/2015', 'Common Grounds', 30608.0),
#  (94395.0, 'Hortense', 'Mapplebeck', 'hmapplebeck2c@google.com.br', '27/05/2017', 'Common Grounds', 40767.0),
#  (46940.0, 'Christian', 'Maliffe', None, '16/02/2022', 'Early Rise', 53746.0),
#  (59956.0, 'Catina', 'Cowderoy', 'ccowderoy2e@oakley.com', '29/11/2016', 'Early Rise', 37913.0),
#  (47833.0, 'Andreana', 'Fowley', None, '25/11/2013', 'Urban Grind', 37721.0),
#  (82461.0, 'Roland', 'Veeler', 'rveeler2g@last.fm', '10/1/2020', 'Common Grounds', 50183.0),
#  (94872.0, 'Danya', 'Halmkin', 'dhalmkin2h@goo.ne.jp', '24/02/2022', 'Urban Grind', 42094.0),
#  (84323.0, 'Silvano', 'Urvoy', None, '12/2/2012', 'Common Grounds', 47045.0),
#  (8036.0, 'Fancy', 'Ogle', 'fogle2j@senate.gov', '24/04/2019', 'Urban Grind', 9848.0),
#  (40433.0, 'Lin', 'West-Frimley', 'lwestfrimley2k@ask.com', '6/1/2022', 'Urban Grind', 34960.0),
#  (88625.0, 'Marabel', 'Jewess', 'mjewess2l@wsj.com', '20/08/2020', 'Early Rise', 63532.0),
#  (4124.0, 'Candice', 'Brasse', 'cbrasse2m@homestead.com', '10/10/2016', 'Early Rise', 67797.0),
#  (29728.0, 'Pauline', 'Geer', 'pgeer2n@ca.gov', '24/06/2021', 'Common Grounds', 65636.0),
#  (20957.0, 'Madison', 'Rudram', 'mrudram2o@is.gd', '16/06/2015', 'Early Rise', 26738.0),
#  (54628.0, 'Giffy', 'Creeboe', 'gcreeboe2p@japanpost.jp', '16/10/2013', 'Common Grounds', 55532.0),
#  (20192.0, 'Tracee', 'Iorizzi', 'tiorizzi2q@stanford.edu', '30/09/2021', 'Early Rise', 10051.0),
#  (69997.0, 'Drew', 'Gokes', None, '23/05/2022', 'Common Grounds', 49343.0)]

# %%
# %sql SELECT * FROM employee;
# Out:
#  * mssql+pymssql://tranghoang:***@DESKTOP-184SUKT/SQLwithPython
# Done.
# [(1037, 'Pearce', 'Drinan', 'pdrinanw@comsenz.com', datetime.date(2023, 2, 4), 'Early Rise', 16557),
#  (1091, 'Nolana', 'Feavearyear', 'nfeavearyear1g@yellowpages.com', datetime.date(2013, 11, 17), 'Early Rise', 66580),
#  (2472, 'Jabez', 'Boatright', 'jboatright17@cdbaby.com', datetime.date(2012, 3, 30), 'Urban Grind', 37117),
#  (4058, 'Grover', 'McGoldrick', 'gmcgoldrick7@prnewswire.com', datetime.date(2020, 5, 22), 'Common Grounds', 57471),
#  (4124, 'Candice', 'Brasse', 'cbrasse2m@homestead.com', datetime.date(2016, 10, 10), 'Early Rise', 67797),
#  (5452, 'Ivie', 'Shynn', 'ishynn8@ucoz.ru', datetime.date(2022, 3, 27), 'Early Rise', 31542),
#  (8036, 'Fancy', 'Ogle', 'fogle2j@senate.gov', datetime.date(2019, 4, 24), 'Urban Grind', 9848),
#  (8194, 'Jeffrey', 'Curran', 'jcurran5@scribd.com', datetime.date(2014, 6, 23), 'Urban Grind', 22986),
#  (8413, 'Vikky', 'Kelcey', 'vkelcey1t@sciencedirect.com', datetime.date(2014, 7, 27), 'Common Grounds', 65685),
#  (10854, 'Meade', 'Makey', 'mmakey1l@europa.eu', datetime.date(2020, 2, 15), 'Urban Grind', 65513),
#  (11497, 'Hermia', 'Sitlington', 'hsitlington1o@arizona.edu', datetime.date(2012, 4, 14), 'Urban Grind', 55136),
#  (12133, 'Jermaine', 'Borleace', 'jborleace16@woothemes.com', datetime.date(2021, 11, 25), 'Common Grounds', 58816),
#  (13244, 'Marybelle', 'Craft', 'mcraft10@macromedia.com', datetime.date(2021, 10, 24), 'Urban Grind', 42076),
#  (14691, 'Ced', 'Marsh', 'cmarsh1n@google.com', datetime.date(2020, 8, 28), 'Early Rise', 33527),
#  (15212, 'Terra', 'Bister', 'tbisteru@sakura.ne.jp', datetime.date(2015, 7, 25), 'Early Rise', 47745),
#  (16025, 'Lorenza', 'Holleworth', 'lholleworth24@state.tx.us', datetime.date(2020, 5, 27), 'Early Rise', 32202),
#  (18551, 'Gert', 'Screeton', 'gscreetonn@nba.com', datetime.date(2021, 8, 1), 'Early Rise', 66121),
#  (19546, 'Marja', 'Halt', 'mhalt29@webs.com', datetime.date(2013, 11, 6), 'Common Grounds', 55570),
#  (19965, 'Leilah', 'Wildbore', 'lwildbore9@amazon.com', datetime.date(2023, 2, 21), 'Common Grounds', 20559),
#  (20192, 'Tracee', 'Iorizzi', 'tiorizzi2q@stanford.edu', datetime.date(2021, 9, 30), 'Early Rise', 10051),
#  (20957, 'Madison', 'Rudram', 'mrudram2o@is.gd', datetime.date(2015, 6, 16), 'Early Rise', 26738),
#  (21218, 'Derrick', 'Hethron', 'dhethroni@ucla.edu', datetime.date(2015, 3, 6), 'Common Grounds', 30453),
#  (23754, 'Zilvia', 'Gingell', 'zgingell1s@columbia.edu', datetime.date(2021, 5, 28), 'Common Grounds', 47782),
#  (23960, 'Elinore', 'Phittiplace', 'ephittiplace1h@alexa.com', datetime.date(2018, 12, 21), 'Urban Grind', 13560),
#  (27157, 'Idalia', 'Guillot', 'iguillot1j@skyrock.com', datetime.date(2022, 9, 30), 'Common Grounds', 35995),
#  (29728, 'Pauline', 'Geer', 'pgeer2n@ca.gov', datetime.date(2021, 6, 24), 'Common Grounds', 65636),
#  (36338, 'Rosetta', 'MacConnulty', 'rmacconnultyt@narod.ru', datetime.date(2012, 7, 13), 'Urban Grind', 61653),
#  (37337, 'Tobye', 'McClinton', 'tmcclintonz@chron.com', datetime.date(2020, 6, 3), 'Early Rise', 26506),
#  (38742, 'Mychal', 'Idill', 'midill1m@plala.or.jp', datetime.date(2018, 7, 23), 'Early Rise', 61899),
#  (40433, 'Lin', 'West-Frimley', 'lwestfrimley2k@ask.com', datetime.date(2022, 1, 6), 'Urban Grind', 34960),
#  (41410, 'Baryram', 'Eddis', 'beddis1k@accuweather.com', datetime.date(2016, 11, 1), 'Early Rise', 43402),
#  (42319, 'Base', 'Amoss', 'bamoss21@1688.com', datetime.date(2019, 5, 18), 'Early Rise', 14716),
#  (43553, 'Gratia', 'Tolussi', 'gtolussi28@bloglines.com', datetime.date(2019, 10, 14), 'Common Grounds', 27925),
#  (43994, 'Cherey', 'Labrenz', 'clabrenz23@unicef.org', datetime.date(2010, 2, 4), 'Urban Grind', 41555),
#  (44757, 'Corrina', 'Basilone', 'cbasilonek@bbb.org', datetime.date(2014, 10, 17), 'Urban Grind', 64204),
#  (45701, 'Abelard', 'MacDougall', 'amacdougalle@comsenz.com', datetime.date(2020, 9, 8), 'Common Grounds', 11433),
#  (49009, 'Cary', 'Brauninger', 'cbrauninger1@independent.co.uk', datetime.date(2014, 8, 26), 'Common Grounds', 45036),
#  (52875, 'Claretta', 'Brient', 'cbrient19@google.fr', datetime.date(2011, 11, 3), 'Urban Grind', 29728),
#  (54628, 'Giffy', 'Creeboe', 'gcreeboe2p@japanpost.jp', datetime.date(2013, 10, 16), 'Common Grounds', 55532),
#  (54733, 'Vonni', 'Davsley', 'vdavsley0@joomla.org', datetime.date(2016, 3, 21), 'Urban Grind', 9253),
#  (59956, 'Catina', 'Cowderoy', 'ccowderoy2e@oakley.com', datetime.date(2016, 11, 29), 'Early Rise', 37913),
#  (60495, 'Aimee', 'Arthan', 'aarthan11@epa.gov', datetime.date(2016, 2, 20), 'Early Rise', 67620),
#  (62627, 'Anne', 'Kohnert', 'akohnert12@arizona.edu', datetime.date(2015, 1, 13), 'Common Grounds', 17675),
#  (63323, 'Maria', 'Schleswig-Holstein', 'mschleswigholstein1u@eventbrite.com', datetime.date(2020, 12, 17), 'Urban Grind', 50603),
#  (66608, 'Earvin', 'Kermott', 'ekermott1b@hostgator.com', datetime.date(2020, 1, 2), 'Common Grounds', 49253),
#  (69050, 'Alta', 'Iredale', 'airedale27@ucoz.com', datetime.date(2019, 9, 14), 'Common Grounds', 61446),
#  (69448, 'Norry', 'MacAdam', 'nmacadamm@ucla.edu', datetime.date(2022, 3, 17), 'Urban Grind', 28640),
#  (69452, 'Analiese', 'Parker', 'aparker1i@auda.org.au', datetime.date(2022, 6, 23), 'Common Grounds', 40807),
#  (70518, 'Liam', 'Fisbburne', 'lfisbburnec@canalblog.com', datetime.date(2023, 1, 10), 'Urban Grind', 24392),
#  (71408, 'Merry', 'Filkin', 'mfilkinx@prweb.com', datetime.date(2016, 8, 19), 'Common Grounds', 65494),
#  (73681, 'Anabelle', 'Bianco', 'abianco6@fotki.com', datetime.date(2016, 5, 4), 'Urban Grind', 50899),
#  (73862, 'Poppy', 'Mattiessen', 'pmattiessen18@ebay.com', datetime.date(2012, 11, 27), 'Common Grounds', 21846),
#  (76862, 'Shell', 'Dumbrell', 'sdumbrell1d@taobao.com', datetime.date(2010, 9, 11), 'Urban Grind', 63533),
#  (79816, 'Cyrillus', 'Hug', 'chug2b@jimdo.com', datetime.date(2015, 4, 3), 'Common Grounds', 30608),
#  (81457, 'Bennett', 'Mebes', 'bmebesf@123-reg.co.uk', datetime.date(2012, 3, 18), 'Common Grounds', 33651),
#  (82297, 'Alanna', 'Rowell', 'arowell1r@friendfeed.com', datetime.date(2022, 9, 4), 'Early Rise', 16377),
#  (82450, 'Clemens', 'Culver', 'cculver1x@cbsnews.com', datetime.date(2021, 12, 8), 'Urban Grind', 40162),
#  (82461, 'Roland', 'Veeler', 'rveeler2g@last.fm', datetime.date(2020, 1, 10), 'Common Grounds', 50183),
#  (83932, 'Sacha', 'Getten', 'sgetten14@fotki.com', datetime.date(2011, 7, 5), 'Early Rise', 56947),
#  (86534, 'Brady', 'Clothier', 'bclothierg@microsoft.com', datetime.date(2019, 12, 20), 'Early Rise', 62386),
#  (86922, 'Rollo', 'Pilgram', 'rpilgraml@booking.com', datetime.date(2021, 6, 12), 'Early Rise', 44894),
#  (88625, 'Marabel', 'Jewess', 'mjewess2l@wsj.com', datetime.date(2020, 8, 20), 'Early Rise', 63532),
#  (90279, 'Lindsay', 'Frankland', 'lfranklanda@japanpost.jp', datetime.date(2022, 5, 20), 'Common Grounds', 10402),
#  (90963, 'Darin', 'Pithie', 'dpithier@studiopress.com', datetime.date(2014, 10, 20), 'Urban Grind', 61056),
#  (91642, 'Noby', 'Leng', 'nleng15@tinyurl.com', datetime.date(2016, 5, 17), 'Common Grounds', 57547),
#  (92473, 'Christoforo', 'Blais', 'cblais26@amazon.co.uk', datetime.date(2019, 2, 16), 'Early Rise', 22592),
#  (93911, 'Cecilla', 'Chesman', 'cchesmanp@bizjournals.com', datetime.date(2014, 12, 21), 'Urban Grind', 38341),
#  (93937, 'Teddy', 'Sterling', 'tsterling1w@ucoz.com', datetime.date(2012, 11, 19), 'Urban Grind', 53767),
#  (94395, 'Hortense', 'Mapplebeck', 'hmapplebeck2c@google.com.br', datetime.date(2017, 5, 27), 'Common Grounds', 40767),
#  (94533, 'Rora', 'Whereat', 'rwhereat1p@dion.ne.jp', datetime.date(2018, 6, 18), 'Urban Grind', 59639),
#  (94872, 'Danya', 'Halmkin', 'dhalmkin2h@goo.ne.jp', datetime.date(2022, 2, 24), 'Urban Grind', 42094),
#  (97247, 'Dinny', 'Shannahan', 'dshannahan20@linkedin.com', datetime.date(2011, 4, 21), 'Early Rise', 21209),
#  (97654, 'Kimmy', 'Arnecke', 'karnecke1z@cyberchimps.com', datetime.date(2020, 5, 1), 'Early Rise', 29915),
#  (98190, 'Elwira', 'Bronot', 'ebronoty@google.cn', datetime.date(2021, 2, 11), 'Common Grounds', 22779)]

# %%
# Order by employee's first name who works at Early Rise shop ASCENDING
# %sql SELECT first_name, last_name, email, salary FROM employee WHERE shop_name = 'Early Rise' ORDER BY first_name ASC
# Out:
#  * mssql+pymssql://tranghoang:***@DESKTOP-184SUKT/SQLwithPython
# Done.
# [('Aimee', 'Arthan', 'aarthan11@epa.gov', 67620),
#  ('Alanna', 'Rowell', 'arowell1r@friendfeed.com', 16377),
#  ('Baryram', 'Eddis', 'beddis1k@accuweather.com', 43402),
#  ('Base', 'Amoss', 'bamoss21@1688.com', 14716),
#  ('Brady', 'Clothier', 'bclothierg@microsoft.com', 62386),
#  ('Candice', 'Brasse', 'cbrasse2m@homestead.com', 67797),
#  ('Catina', 'Cowderoy', 'ccowderoy2e@oakley.com', 37913),
#  ('Ced', 'Marsh', 'cmarsh1n@google.com', 33527),
#  ('Christoforo', 'Blais', 'cblais26@amazon.co.uk', 22592),
#  ('Dinny', 'Shannahan', 'dshannahan20@linkedin.com', 21209),
#  ('Gert', 'Screeton', 'gscreetonn@nba.com', 66121),
#  ('Ivie', 'Shynn', 'ishynn8@ucoz.ru', 31542),
#  ('Kimmy', 'Arnecke', 'karnecke1z@cyberchimps.com', 29915),
#  ('Lorenza', 'Holleworth', 'lholleworth24@state.tx.us', 32202),
#  ('Madison', 'Rudram', 'mrudram2o@is.gd', 26738),
#  ('Marabel', 'Jewess', 'mjewess2l@wsj.com', 63532),
#  ('Mychal', 'Idill', 'midill1m@plala.or.jp', 61899),
#  ('Nolana', 'Feavearyear', 'nfeavearyear1g@yellowpages.com', 66580),
#  ('Pearce', 'Drinan', 'pdrinanw@comsenz.com', 16557),
#  ('Rollo', 'Pilgram', 'rpilgraml@booking.com', 44894),
#  ('Sacha', 'Getten', 'sgetten14@fotki.com', 56947),
#  ('Terra', 'Bister', 'tbisteru@sakura.ne.jp', 47745),
#  ('Tobye', 'McClinton', 'tmcclintonz@chron.com', 26506),
#  ('Tracee', 'Iorizzi', 'tiorizzi2q@stanford.edu', 10051)]

# %%
# Find which shop has the highest number of employee
# %sql SELECT shop_name, COUNT(*) as Employees FROM employee GROUP BY shop_name ORDER BY Employees DESC
# Out:
#  * mssql+pymssql://tranghoang:***@DESKTOP-184SUKT/SQLwithPython
# Done.
# [('Common Grounds', 26), ('Early Rise', 24), ('Urban Grind', 24)]

# %%
# Find which shop has the lowest average salary
# %sql SELECT shop_name,COUNT(*) as Employees,ROUND(AVG(salary),0) as AVGSalary FROM employee GROUP BY shop_name ORDER BY AVGSalary
# Out:
#  * mssql+pymssql://tranghoang:***@DESKTOP-184SUKT/SQLwithPython
# Done.
# [('Early Rise', 24, 40365),
#  ('Common Grounds', 26, 41551),
#  ('Urban Grind', 24, 41696)]
